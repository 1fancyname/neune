# %% [markdown]
# ---
# title: The Perceptron as a binary Classifier
# ---

# %% [markdown]
#  ```{figure} images/2d_perceptron.png
# ---
# name: 2d-perceptron
# alt: 2d-perceptron
# width: 80%
# ---
# **Fig. 1:** 2d-perceptron
